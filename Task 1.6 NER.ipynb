# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module

# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------- ------------------------------ 2.9/12.8 MB 21.0 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 27.9 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 27.6 MB/s  0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.22)
# Requirement already satisfied: jinja2 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (78.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2025.8.3)
# Requirement already satisfied: cloudpickle>=2.2.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from srsly<3.0.0,>=2.4.3->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.1)
# Requirement already satisfied: ujson>=1.35 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from srsly<3.0.0,>=2.4.3->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.11.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.2.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.2.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\beaac\anaconda3\envs\myenv\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.4.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# Load Twentieth-century text file

# %%
with open('key_events_20th_century.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '').strip()

# %%
ountries_list = [
    'United States', 'Russia', 'United Kingdom', 'Germany',
    'France', 'China', 'Japan', 'Italy', 'India', 'Canada'
]

# %%
country_aliases = {
    'USA': 'United States',
    'America': 'United States',
    'USSR': 'Russia',
    'Soviet Union': 'Russia',
    'Britain': 'United Kingdom',
    'England': 'United Kingdom',
    'PRC': 'China',
    'Nippon': 'Japan'
}

# %%
for alias, standard in country_aliases.items():
    if alias in data:
        print(f"Found alias: {alias} → Replace with: {standard}")
        data = data.replace(alias, standard)
# Out:
# Found alias: USA → Replace with: United States
# Found alias: America → Replace with: United States
# Found alias: USSR → Replace with: Russia
# Found alias: Soviet Union → Replace with: Russia
# Found alias: Britain → Replace with: United Kingdom

# %%
with open('key_events_20th_century_cleaned.txt', 'w', encoding='utf-8') as file:
    file.write(data)

# %% [markdown]
# # Text Wrangling Observations
# Country names in the text did not always match the standardized list. For example:
# "USA" was replaced with "United States"
# "America" was replaced with "United Sates"
# "Soviet Union" and "USSR" were replaced with "Russia"
# "Britain" and "England" were replaced with "United Kingdom"
# These corrections were made to ensure consistency for Named Entity Recognition and network analysis.
# The cleaned version of the text was saved as key_events_20th_century_cleaned.txt.

# %%
# Load Cleaned version 
with open('key_events_20th_century_cleaned.txt', 'r', encoding='utf-8') as file:
    cleaned_data = file.read()

# %%
book= NER(cleaned_data)

# %%
displacy.render(book[273:20000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Franz Ferdinand, by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gavrilo Princip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a member of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Young Bosnia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  liberation movement. After a period of diplomatic and military escalation known as
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the July Crisis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of July 1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  two coalitions were at war: the Allies, comprised initially of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Russian Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ; and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , comprised initially of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria-Hungary.[1][2]In 1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ended hostile actions against
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  after the fall of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tsar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The Bolsheviks negotiated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Treaty of Brest-Litovsk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , although it was a huge cost to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In the treaty,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolshevik Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ceded the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baltic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  states to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and its province of
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kars Oblast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  in the South Caucasus to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ottoman Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . It also recognized the independence of Ukraine.[3] Although
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  shifted huge forces from the eastern to the western front after signing the treaty, it was unable to stop the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Allied
#     <span style="font-size: 0.8em; font-weight: bold; line-hei

# %%
#Split the setence entities from the NER object
df_sentences = []

for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents] 
    df_sentences.append({"sentence": sent.text, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  The 20th century changed the world in unpreced...
# 1  The World Wars sparked tension between countri...
# 2  These advancements have played a significant r...
# 3  Historic events in the 20th century[edit]World...
# 4  Edwardian eraThe new beginning of the 20th cen...
# 5  The 1900s saw the decade herald a series of in...
# 6       1914 saw the completion of the Panama Canal.
# 7  The Scramble for Africa continued in the 1900s...
# 8  The atrocities in the Congo Free State shocked...
# 9  From 1914 to 1918, the First World War, and it...
#
#                               entities
# 0                   [The 20th century]
# 1       [the Cold War, the Space Race]
# 2            [the 21st century, today]
# 3                           [the 20th]
# 4        [Edwardian, the 20th century]
# 5              [The 1900s, the decade]
# 6             [1914, the Panama Canal]
# 7        [Scramble, Africa, the 1900s]
# 8               [the Congo Free State]
# 9  [1914 to 1918, the First World War]

# %%
#Load countries list 
df_countries= pd.read_csv(r"C:\Users\beaac\Desktop\20 Century\countries_list_20th_century_1.5 (1).csv")

# %%
print(df_countries.columns)
# Out:
# Index(['Unnamed: 0', 'country_name'], dtype='object')

# %%
countries = df_countries['country_name'].dropna().tolist()

# %%
print(countries[:10])  # Preview first 10 entries
# Out:
# [' Afghanistan ', '  Albania ', '  Algeria ', '  Andorra ', '  Angola ', '  Antigua and Barbuda ', '  Argentina ', '  Armenia ', '  Australia ', '  Austria ']

# %%
print(df_sentences.head(10))
# Out:
#                                             sentence  \
# 0  The 20th century changed the world in unpreced...
# 1  The World Wars sparked tension between countri...
# 2  These advancements have played a significant r...
# 3  Historic events in the 20th century[edit]World...
# 4  Edwardian eraThe new beginning of the 20th cen...
# 5  The 1900s saw the decade herald a series of in...
# 6       1914 saw the completion of the Panama Canal.
# 7  The Scramble for Africa continued in the 1900s...
# 8  The atrocities in the Congo Free State shocked...
# 9  From 1914 to 1918, the First World War, and it...
#
#                               entities country_entities
# 0                   [The 20th century]               []
# 1       [the Cold War, the Space Race]               []
# 2            [the 21st century, today]               []
# 3                           [the 20th]               []
# 4        [Edwardian, the 20th century]               []
# 5              [The 1900s, the decade]               []
# 6             [1914, the Panama Canal]               []
# 7        [Scramble, Africa, the 1900s]               []
# 8               [the Congo Free State]               []
# 9  [1914 to 1918, the First World War]               []

# %%
countries = [c.strip().lower() for c in df_countries['country_name'].dropna()]

# %%
def filter_country_entities(ent_list, countries):
    return [ent for ent in ent_list if ent.strip().lower() in countries]

# %%
df_sentences["country_entities"] = df_sentences["entities"].apply(
    lambda x: filter_country_entities(x, countries)
)

# %%
df_sentences_filtered = df_sentences[df_sentences["country_entities"].map(len) > 0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 884   "The Philippines, 1898â€“1946 | US House of Re...
# 906   "Colonial Cartographies, Postcolonial Borders,...
# 925   "The Incorporation of the Baltic States by the...
# 935   The Moldovans: Romania, Russia, and the Politi...
# 981   "Selling 'Operation Passage to Freedom': Dr. T...
# 1004  "Stuck in Endless Preliminaries: Vietnam and t...
# 1092  "The forgotten story of how the Baltic states ...
# 1206  "Anti-United Statesn Behavior in the Middle Ea...
# 1210    The Rise of China and India: A New Asian Drama.
# 1211                       Singapore: World Scientific.
#
#                                                entities   country_entities
# 884      [Philippines, 1898â€“1946, US, Art & Archives]      [Philippines]
# 906   [Colonial Cartographies, Enduring Failures of ...      [Afghanistan]
# 925    [The Incorporation of the Baltic States, Russia]           [Russia]
# 935   [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 981   [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1004  [Vietnam, the Battle of the Paris Peace Table,...          [Vietnam]
# 1092                                   [Baltic, Russia]           [Russia]
# 1206     [the Middle East, a Field Experiment, Lebanon]          [Lebanon]
# 1210                         [The Rise of China, India]            [India]
# 1211                                        [Singapore]        [Singapore]

# %% [markdown]
#  Create Relationships

# %%
# Define window size (e.g., 5 sentences at a time)
window_size = 5
relationships = []


for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i + 5, df_sentences_filtered.index[-1])
    
    # Flatten country entities from the window
    country_list = sum(df_sentences_filtered.loc[i:end_i]["country_entities"], [])
    
    # Remove adjacent duplicates
    country_unique = [country_list[i] for i in range(len(country_list))
                      if i == 0 or country_list[i] != country_list[i - 1]]
    
    # Build pairwise relationships
    if len(country_unique) > 1:
        for idx, a in enumerate(country_unique[:-1]):
            b = country_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#      source     target
# 0    Russia     France
# 1    Russia     France
# 2    France     Russia
# 3    Russia    Germany
# 4    Russia     France
# ..      ...        ...
# 800   India  Singapore
# 801   India  Singapore
# 802   India  Singapore
# 803   India  Singapore
# 804   India  Singapore
#
# [805 rows x 2 columns]

# %%
# Sort the cases with a- >b and b- >a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#     source  target
# 0   France  Russia
# 1   France  Russia
# 2   France  Russia
# 3  Germany  Russia
# 4   France  Russia

# %%
#Summarize interactions
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
relationship_df.head(10)
# Out:
#     source          target  value
# 0   France          Russia     23
# 1  Germany          Russia     26
# 2  Germany           Italy     12
# 3  Austria         Germany     11
# 4  Germany           Spain      1
# 5   Russia           Spain      4
# 6   Poland          Russia     40
# 7   France          Poland     11
# 8   France  United Kingdom     14
# 9   Poland  United Kingdom     11

# %%
relationship_df.to_csv('Countries_relationship.csv')
